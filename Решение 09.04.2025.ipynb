# %% [markdown]
# ## Поиск проблемы

# %%
import pandas as pd

# %%
orders = pd.read_csv("orders.csv")
device = pd.read_csv("device.csv")
display(orders)
display(device)
# Out:
#      order_id                      order  order_price  user_id
# 0         999       Мясной микс, 3 пиццы         1878   102475
# 1         680                Мясной микс          579   218841
# 2         687                Мясной микс          579   521065
# 3         685                     Дьябло          560   106146
# 4         683                Сицилийская          545   854950
# ..        ...                        ...          ...      ...
# 995       917                Четыре сыра          499   957570
# 996       919                Четыре сыра          499   957570
# 997       918                        NaN         1080   957570
# 998       948                        NaN          560   976203
# 999       947  Пеперони, 3 пиццы, Дьябло         2389   684541
#
# [1000 rows x 4 columns]
#                   ip   device      operator_ip  user_id
# 0     192.168.66.187  unknown  192.168.215.115   102475
# 1    192.168.100.221   mobile  192.168.203.103   218841
# 2    192.168.100.221   mobile  192.168.202.102   521065
# 3    192.168.100.221      web  192.168.212.112   106146
# 4    192.168.100.221   mobile  192.168.217.117   854950
# ..               ...      ...              ...      ...
# 995   192.168.42.163   mobile  192.168.216.116   957570
# 996   192.168.42.163   mobile  192.168.205.105   957570
# 997   192.168.42.163  unknown  192.168.205.105   957570
# 998   192.168.79.200  unknown  192.168.213.113   976203
# 999   192.168.79.200   mobile  192.168.205.105   684541
#
# [1000 rows x 4 columns]

# %%
(orders["user_id"] == device["user_id"]).sum()
# Out:
# 1000

# %% [markdown]
# Колонки user_id в наших датафреймах не просто выступают уникальными идентификаторами, но ещё и записаны с идеальной очерёдностью - поэтому наши датафреймы можно просто "склеить" друг с другом по горизонтали:

# %%
df = pd.concat([orders, device], axis=1)
df = df.loc[:,~df.columns.duplicated()].copy() # удаляем лишний столбец user_id за ненадобностью - после объединения он оказался продублирован
df
# Out:
#      order_id                      order  order_price  user_id  \
# 0         999       Мясной микс, 3 пиццы         1878   102475
# 1         680                Мясной микс          579   218841
# 2         687                Мясной микс          579   521065
# 3         685                     Дьябло          560   106146
# 4         683                Сицилийская          545   854950
# ..        ...                        ...          ...      ...
# 995       917                Четыре сыра          499   957570
# 996       919                Четыре сыра          499   957570
# 997       918                        NaN         1080   957570
# 998       948                        NaN          560   976203
# 999       947  Пеперони, 3 пиццы, Дьябло         2389   684541
#
#                   ip   device      operator_ip
# 0     192.168.66.187  unknown  192.168.215.115
# 1    192.168.100.221   mobile  192.168.203.103
# 2    192.168.100.221   mobile  192.168.202.102
# 3    192.168.100.221      web  192.168.212.112
# 4    192.168.100.221   mobile  192.168.217.117
# ..               ...      ...              ...
# 995   192.168.42.163   mobile  192.168.216.116
# 996   192.168.42.163   mobile  192.168.205.105
# 997   192.168.42.163  unknown  192.168.205.105
# 998   192.168.79.200  unknown  192.168.213.113
# 999   192.168.79.200   mobile  192.168.205.105
#
# [1000 rows x 7 columns]

# %% [markdown]
# Первым делом создадим признак `order_missing` - своего рода таргет, который показывает, пропущено ли значение в колонке `order`:

# %%
df["order_missing"] = df["order"].isna()
df["order_missing"]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997     True
# 998     True
# 999    False
# Name: order_missing, Length: 1000, dtype: bool

# %% [markdown]
# Каков масштаб трагедии - сколько значений в колонке `order` пропущено?

# %%
print(f"Количество пропусков в колонке orders: {df["order"].isna().sum()}")
print(f"Доля пропусков в колонке orders: {df["order"].isna().sum() / df.shape[0]}")
# Out:
# Количество пропусков в колонке orders: 269
# Доля пропусков в колонке orders: 0.269

# %% [markdown]
# Итак, имеем дело с примерно 27% пропусков - довольно много.

# %% [markdown]
# Посмотрим на колонку `operator_ip` поподробнее - а именно на её уникальные значения и их количество:

# %%
print(f"IP-адреса операторов: {df["operator_ip"].unique()}")
print(f"Количество операторов в выборке: {len(df["operator_ip"].unique())}")
# Out:
# IP-адреса операторов: ['192.168.215.115' '192.168.203.103' '192.168.202.102' '192.168.212.112'
#  '192.168.217.117' '192.168.209.109' '192.168.213.113' '192.168.208.108'
#  '192.168.216.116' '192.168.204.104' '192.168.211.111' '192.168.206.106'
#  '192.168.85.206' '192.168.205.105' '192.168.214.114' '192.168.207.107'
#  '192.168.210.110' '192.168.91.212' '192.168.218.118' '192.168.46.167']
# Количество операторов в выборке: 20

# %% [markdown]
# С помощью сводной таблицы проверим, что проблема не в операторах:

# %%
df.pivot_table(index="operator_ip", values="order_missing", aggfunc="sum").plot(kind="bar", xlabel="IP-адрес оператора", ylabel="Количество пропусков у оператора");

# %% [markdown]
# Как видим, особых аномалий у операторов не наблюдается - значит, никто из них, скорее всего, не "виноват" в потере данных.
#
# Переходим к `order_id`: насколько я понял, id каждому заказу выдаётся по порядку - сначала 001, потом 002, и так далее до 999, а затем снова 001. Таким образом, можно использовать эту колонку как своего рода временной ряд и, если проблема возникла в какое-то определённое время, отследить её:

# %%
df["order_id_group"] = df["order_id"].apply(lambda x: str(x)[0])
df.pivot_table(index="order_id_group", values="order_missing", aggfunc="sum").plot(kind="bar", xlabel="Первая цифра номера заказа", ylabel="Количество пропусков в заказах с этой первой цифрой номера");

# %% [markdown]
# Как видим, проблема произошла не в какое-то определённое время, поскольку распределение пропусков по заказам довольно равномерное.

# %% [markdown]
# Возможно, проблема с IP-адресами клиентов? Посмотрим на распределение

# %%
df_pivot_ip = df.pivot_table(index="ip", values="order_missing", aggfunc="sum")
df_pivot_ip["ip"] = df_pivot_ip.index
df_pivot_ip.plot(kind="scatter", x="ip", y="order_missing");

# %%
df_pivot_ip.loc[df_pivot_ip["order_missing"] >= 10, "order_missing"].sort_values(ascending=False).plot(kind="bar", y="order_missing", ylabel="Количество пропущенных значений", xlabel="IP-адрес");

# %%
anomaly_operators = df[lambda df: df["ip"].isin(["192.168.27.148", "192.168.47.168", "192.168.4.125", "192.168.84.205", "192.168.96.217"])]
anomaly_operators_pivot_missing = anomaly_operators.pivot_table(index="ip", values="order", aggfunc=[lambda x: x.isna().sum(), lambda x: x.isna().sum() / x.shape[0]])
anomaly_operators_pivot_missing.iloc[:, 1].plot(kind="bar", ylabel="Доля пропусов среди всех строк с этим ip-адресом");

# %% [markdown]
# ## Заполнение пропусков

# %% [markdown]
# Создадим таблицу с "меню" ресторана:

# %%
menu = df.pivot_table(index="order", values="order_price", aggfunc=lambda x: x.mode()[0])
menu
# Out:
#                                   order_price
# order
# 3 пиццы                                  1299
# 3 пиццы, Вегетарианская                  1809
# 3 пиццы, Гавайская                       1819
# 3 пиццы, Гавайская, Сицилийская          2364
# 3 пиццы, Дьябло                          1859
# ...                                       ...
# Четыре сыра, Маргарита                    978
# Четыре сыра, Маргарита, Пеперони         1508
# Четыре сыра, Мясной микс                 1078
# Четыре сыра, Пеперони                    1029
# Четыре сыра, Сицилийская                 1044
#
# [156 rows x 1 columns]

# %%
menu_one_item = menu[~menu.index.str.contains(',')]
menu_one_item
# Out:
#                 order_price
# order
# 3 пиццы                1299
# Вегетарианская          510
# Гавайская               520
# Дьябло                  560
# Маргарита               479
# Мясной микс             579
# Неаполитанская          530
# Пеперони                530
# Сицилийская             545
# Четыре сыра             499

# %% [markdown]
# Как видим, цены всех пицц, кроме Неаполитанской и Пеперони, уникальны - это даёт нам возможность однозначно заполнить все пропуски, где по цене видно, что в заказе только одна пицца (кроме случаев, когда цена равна 530 - это разберём далее).
#
# Реализуем это:

# %%
df_one_pizza = df[df["order_price"].isin(menu_one_item["order_price"])]
df_one_pizza_no_530 = df_one_pizza[df_one_pizza["order_price"] != 530]
df_one_pizza_no_530.isna().sum()
# Out:
# order_id            0
# order             146
# order_price         0
# user_id             0
# ip                  0
# device              0
# operator_ip         0
# order_missing       0
# order_id_group      0
# dtype: int64

# %%
price_to_pizza = dict(zip(menu_one_item['order_price'], menu_one_item.index))
price_to_pizza
# Out:
# {1299: '3 пиццы',
#  510: 'Вегетарианская',
#  520: 'Гавайская',
#  560: 'Дьябло',
#  479: 'Маргарита',
#  579: 'Мясной микс',
#  530: 'Пеперони',
#  545: 'Сицилийская',
#  499: 'Четыре сыра'}

# %%
for index, row in df_one_pizza_no_530.iterrows():
    if pd.isnull(row['order']):
        order_price = row['order_price']
        df_one_pizza_no_530.at[index, 'order'] = price_to_pizza[order_price]
df_one_pizza_no_530
# Out:
#      order_id           order  order_price  user_id               ip   device  \
# 1         680     Мясной микс          579   218841  192.168.100.221   mobile
# 2         687     Мясной микс          579   521065  192.168.100.221   mobile
# 3         685          Дьябло          560   106146  192.168.100.221      web
# 4         683     Сицилийская          545   854950  192.168.100.221   mobile
# 9         688  Вегетарианская          510   896258  192.168.100.221  unknown
# ..        ...             ...          ...      ...              ...      ...
# 990       804       Гавайская          520   249932   192.168.30.151   mobile
# 991       802  Вегетарианская          510   796033   192.168.30.151      web
# 995       917     Четыре сыра          499   957570   192.168.42.163   mobile
# 996       919     Четыре сыра          499   957570   192.168.42.163   mobile
# 998       948          Дьябло          560   976203   192.168.79.200  unknown
#
#          operator_ip  order_missing order_id_group
# 1    192.168.203.103          False              6
# 2    192.168.202.102          False              6
# 3    192.168.212.112          False              6
# 4    192.168.217.117          False              6
# 9    192.168.216.116          False              6
# ..               ...            ...            ...
# 990   192.168.85.206          False              8
# 991  192.168.206.106          False              8
# 995  192.168.216.116          False              9
# 996  192.168.205.105          False              9
# 998  192.168.213.113           True              9
#
# [534 rows x 9 columns]

# %% [markdown]
# Успешно заполнили все пропуски, в которых присутствует только одна пицца, и цена не равна 530. Теперь разберёмся со строками, где цена равна 530:

# %%
df_one_pizza_530 = df[df["order_price"] == 530]
df_one_pizza_530.isna().sum()
# Out:
# order_id           0
# order             39
# order_price        0
# user_id            0
# ip                 0
# device             0
# operator_ip        0
# order_missing      0
# order_id_group     0
# dtype: int64

# %% [markdown]
# Здесь заполним пропуски следующим образом: для каждого `ip` найдём моду по непропущенным значениям `order` (тем самым выясним, какую из двух возможных пицц человек с данным ip-адресом чаще всего заказывает) - и именно этим значением заполним пропуски:

# %%
df_one_pizza_530["ip"].nunique()
# Out:
# 32

# %%
df_pivot_id_modes = df_one_pizza_530[df_one_pizza_530["order"].notna()].groupby("ip").agg(func=lambda x:x.mode()[0])["order"]
for ip in df_pivot_id_modes.index:
    df_one_pizza_530.loc[df_one_pizza_530["ip"] == ip, "order"] = df_one_pizza_530.loc[df_one_pizza_530["ip"] == ip, "order"].fillna(df_pivot_id_modes[ip])
df_one_pizza_530
# Out:
#      order_id           order  order_price  user_id               ip   device  \
# 5         678        Пеперони          530   263835  192.168.100.221      web
# 6         681        Пеперони          530   948406  192.168.100.221   mobile
# 7         696        Пеперони          530   106146  192.168.100.221  unknown
# 8         692        Пеперони          530   657404  192.168.100.221   mobile
# 20        969             NaN          530   603670   192.168.61.182      web
# ..        ...             ...          ...      ...              ...      ...
# 937       428        Пеперони          530   928693   192.168.84.205  unknown
# 938       442        Пеперони          530   739072   192.168.84.205  unknown
# 939       462        Пеперони          530   927623   192.168.84.205   mobile
# 988       801  Неаполитанская          530   682484   192.168.30.151      web
# 989       806        Пеперони          530   941400   192.168.30.151      web
#
#          operator_ip  order_missing order_id_group
# 5    192.168.209.109           True              6
# 6    192.168.213.113           True              6
# 7    192.168.208.108          False              6
# 8    192.168.213.113          False              6
# 20   192.168.209.109           True              9
# ..               ...            ...            ...
# 937   192.168.85.206          False              4
# 938  192.168.210.110          False              4
# 939  192.168.210.110          False              4
# 988  192.168.208.108          False              8
# 989  192.168.211.111          False              8
#
# [141 rows x 9 columns]

# %%
df_one_pizza_530["order"].isna().sum()
# Out:
# 7

# %% [markdown]
# Практически все пропуски заполнены - осталось 7 штук. Их заполним простой модой:

# %%
df_one_pizza_530["order"] = df_one_pizza_530["order"].fillna(df_one_pizza_530["order"].mode()[0])
df_one_pizza_530["order"]
# Out:
# C:\Users\mtkar\AppData\Local\Temp\ipykernel_27128\1686159459.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_one_pizza_530["order"] = df_one_pizza_530["order"].fillna(df_one_pizza_530["order"].mode()[0])
# 5            Пеперони
# 6            Пеперони
# 7            Пеперони
# 8            Пеперони
# 20     Неаполитанская
#             ...
# 937          Пеперони
# 938          Пеперони
# 939          Пеперони
# 988    Неаполитанская
# 989          Пеперони
# Name: order, Length: 141, dtype: object

# %% [markdown]
# Теперь заменим строки в датафрейме df_one_pizzа на строки с соответствующими `order_id` из датафреймов df_one_pizza_no_530 и df_one_pizza_530 - по сути дела, "сохраним наши наработки в исходный датафрейм:

# %%
for order_id in df_one_pizza_530["order_id"]:
    df_one_pizza.loc[df_one_pizza["order_id"] == order_id] = df_one_pizza_530
for order_id in df_one_pizza_no_530["order_id"]:
    df_one_pizza.loc[df_one_pizza["order_id"] == order_id] = df_one_pizza_no_530

df_one_pizza
# Out:
#      order_id           order  order_price  user_id               ip   device  \
# 1         680     Мясной микс          579   218841  192.168.100.221   mobile
# 2         687     Мясной микс          579   521065  192.168.100.221   mobile
# 3         685          Дьябло          560   106146  192.168.100.221      web
# 4         683     Сицилийская          545   854950  192.168.100.221   mobile
# 5         678        Пеперони          530   263835  192.168.100.221      web
# ..        ...             ...          ...      ...              ...      ...
# 990       804       Гавайская          520   249932   192.168.30.151   mobile
# 991       802  Вегетарианская          510   796033   192.168.30.151      web
# 995       917     Четыре сыра          499   957570   192.168.42.163   mobile
# 996       919     Четыре сыра          499   957570   192.168.42.163   mobile
# 998       948          Дьябло          560   976203   192.168.79.200  unknown
#
#          operator_ip  order_missing order_id_group
# 1    192.168.203.103          False              6
# 2    192.168.202.102          False              6
# 3    192.168.212.112          False              6
# 4    192.168.217.117          False              6
# 5    192.168.209.109           True              6
# ..               ...            ...            ...
# 990   192.168.85.206          False              8
# 991  192.168.206.106          False              8
# 995  192.168.216.116          False              9
# 996  192.168.205.105          False              9
# 998  192.168.213.113           True              9
#
# [675 rows x 9 columns]

# %%
df_one_pizza["order"].isna().sum()
# Out:
# 0

# %% [markdown]
# Пропуски в заказах с одной пиццей заполнили. Переходим к заказам с двумя пиццами:

# %%
menu["order"] = menu.index
menu["order"] = menu["order"].apply(lambda order:', '.join(sorted(order.split(', '))))
menu.index=menu["order"]
menu.drop("order", axis=1, inplace=True)
menu_two_items = menu[menu.index.str.count(',') == 1]
menu_two_items
# Out:
#                           order_price
# order
# 3 пиццы, Вегетарианская          1809
# 3 пиццы, Гавайская               1819
# 3 пиццы, Дьябло                  1859
# 3 пиццы, Маргарита               1778
# 3 пиццы, Мясной микс             1878
# ...                               ...
# Дьябло, Четыре сыра              1059
# Маргарита, Четыре сыра            978
# Мясной микс, Четыре сыра         1078
# Пеперони, Четыре сыра            1029
# Сицилийская, Четыре сыра         1044
#
# [80 rows x 1 columns]

# %% [markdown]
# При работе со строками, где присутствует лишь одна пицца, мы столкнулись с двумя пиццами, стоящими одинаково - Неаполитанская и Пеперони. Посмотрим, сколько таких значений в заказах с двумя пиццами:

# %%
(menu_two_items.value_counts() > 1).sum()
# Out:
# 31

# %% [markdown]
# Здесь таких значений уже 31 - почти половина. К их заполнению вернёмся позже, а сейчас заполним однозначные пропуски:

# %%
df_two_pizzas = df[df["order_price"].isin(menu_two_items["order_price"])]
df_two_pizzas
# Out:
#      order_id                        order  order_price  user_id  \
# 0         999         Мясной микс, 3 пиццы         1878   102475
# 14        691                          NaN         1778   176837
# 16        679       Неаполитанская, Дьябло         1090   827595
# 17        695       Вегетарианская, Дьябло         1070   106146
# 18        690          Гавайская, Пеперони         1050   476835
# ..        ...                          ...          ...      ...
# 981       456     Сицилийская, Четыре сыра         1044   548845
# 982       468            Маргарита, Дьябло         1039   823250
# 983       449  Вегетарианская, Четыре сыра         1009   917417
# 992       799         3 пиццы, Мясной микс         1878   681378
# 997       918                          NaN         1080   957570
#
#                   ip   device      operator_ip  order_missing order_id_group
# 0     192.168.66.187  unknown  192.168.215.115          False              9
# 14   192.168.100.221      web  192.168.203.103           True              6
# 16   192.168.100.221   mobile  192.168.216.116          False              6
# 17   192.168.100.221      web  192.168.206.106          False              6
# 18   192.168.100.221   mobile   192.168.85.206          False              6
# ..               ...      ...              ...            ...            ...
# 981   192.168.84.205   mobile  192.168.205.105          False              4
# 982   192.168.84.205  unknown  192.168.213.113          False              4
# 983   192.168.84.205      web  192.168.204.104          False              4
# 992   192.168.30.151  unknown  192.168.202.102          False              7
# 997   192.168.42.163  unknown  192.168.205.105           True              9
#
# [232 rows x 9 columns]

# %%
df_two_pizzas_no_dup = df_two_pizzas[~df_two_pizzas["order"].isin(menu_two_items.loc[menu_two_items.duplicated()].index)]
df_two_pizzas_no_dup.isna().sum()
# Out:
# order_id           0
# order             58
# order_price        0
# user_id            0
# ip                 0
# device             0
# operator_ip        0
# order_missing      0
# order_id_group     0
# dtype: int64

# %%
price_to_pizza = dict(zip(menu_two_items['order_price'], menu_two_items.index))
price_to_pizza
# Out:
# {1809: '3 пиццы, Вегетарианская',
#  1819: '3 пиццы, Гавайская',
#  1859: '3 пиццы, Дьябло',
#  1778: '3 пиццы, Маргарита',
#  1878: '3 пиццы, Мясной микс',
#  1829: '3 пиццы, Пеперони',
#  1844: '3 пиццы, Сицилийская',
#  1798: '3 пиццы, Четыре сыра',
#  1070: 'Вегетарианская, Дьябло',
#  1089: 'Вегетарианская, Мясной микс',
#  1040: 'Вегетарианская, Пеперони',
#  1055: 'Вегетарианская, Сицилийская',
#  1009: 'Вегетарианская, Четыре сыра',
#  1030: 'Вегетарианская, Гавайская',
#  1080: 'Гавайская, Дьябло',
#  999: 'Гавайская, Маргарита',
#  1099: 'Гавайская, Мясной микс',
#  1050: 'Гавайская, Пеперони',
#  1065: 'Гавайская, Сицилийская',
#  1019: 'Гавайская, Четыре сыра',
#  1039: 'Дьябло, Маргарита',
#  1139: 'Дьябло, Мясной микс',
#  1090: 'Дьябло, Пеперони',
#  1105: 'Дьябло, Сицилийская',
#  989: 'Вегетарианская, Маргарита',
#  1058: 'Маргарита, Мясной микс',
#  1024: 'Маргарита, Сицилийская',
#  978: 'Маргарита, Четыре сыра',
#  1109: 'Мясной микс, Неаполитанская',
#  1124: 'Мясной микс, Сицилийская',
#  1060: 'Неаполитанская, Пеперони',
#  1075: 'Пеперони, Сицилийская',
#  1029: 'Пеперони, Четыре сыра',
#  1044: 'Сицилийская, Четыре сыра',
#  1059: 'Дьябло, Четыре сыра',
#  1078: 'Мясной микс, Четыре сыра'}

# %%
for index, row in df_two_pizzas_no_dup.iterrows():
    if pd.isnull(row['order']):
        order_price = row['order_price']
        df_two_pizzas_no_dup.at[index, 'order'] = price_to_pizza[order_price]
df_two_pizzas_no_dup
# Out:
#      order_id                           order  order_price  user_id  \
# 0         999            Мясной микс, 3 пиццы         1878   102475
# 14        691              3 пиццы, Маргарита         1778   176837
# 16        679          Неаполитанская, Дьябло         1090   827595
# 19        694  Вегетарианская, Неаполитанская         1040   502631
# 21        970                Пеперони, Дьябло         1090   110406
# ..        ...                             ...          ...      ...
# 974       416             Мясной микс, Дьябло         1139   693543
# 975       425     Неаполитанская, Мясной микс         1109   410829
# 976       422                Дьябло, Пеперони         1090   724452
# 982       468               Маргарита, Дьябло         1039   823250
# 997       918               Гавайская, Дьябло         1080   957570
#
#                   ip   device      operator_ip  order_missing order_id_group
# 0     192.168.66.187  unknown  192.168.215.115          False              9
# 14   192.168.100.221      web  192.168.203.103           True              6
# 16   192.168.100.221   mobile  192.168.216.116          False              6
# 19   192.168.100.221      web  192.168.205.105          False              6
# 21    192.168.61.182      web  192.168.209.109          False              9
# ..               ...      ...              ...            ...            ...
# 974   192.168.84.205  unknown   192.168.46.167          False              4
# 975   192.168.84.205      web  192.168.207.107          False              4
# 976   192.168.84.205   mobile  192.168.214.114           True              4
# 982   192.168.84.205  unknown  192.168.213.113          False              4
# 997   192.168.42.163  unknown  192.168.205.105           True              9
#
# [159 rows x 9 columns]

# %%
df_two_pizzas_no_dup["order"].isna().sum()
# Out:
# 0

# %% [markdown]
# Все строки с двумя пиццами, которые можно было заполнить однозначно, заполнили.
#
# Перейдём к заполнению остальных пропусков:

# %%
df_two_pizzas_dup = df_two_pizzas[df_two_pizzas["order"].isin(menu_two_items.loc[menu_two_items.duplicated()].index)]
df_two_pizzas_dup
# Out:
#      order_id                        order  order_price  user_id  \
# 17        695       Вегетарианская, Дьябло         1070   106146
# 18        690          Гавайская, Пеперони         1050   476835
# 37        875         Гавайская, Маргарита          999   907417
# 83        626              3 пиццы, Дьябло         1859   833717
# 86        617      3 пиццы, Неаполитанская         1829   830589
# ..        ...                          ...          ...      ...
# 979       417        Пеперони, Сицилийская         1075   706211
# 980       424     Неаполитанская, Пеперони         1060   593492
# 981       456     Сицилийская, Четыре сыра         1044   548845
# 983       449  Вегетарианская, Четыре сыра         1009   917417
# 992       799         3 пиццы, Мясной микс         1878   681378
#
#                   ip   device      operator_ip  order_missing order_id_group
# 17   192.168.100.221      web  192.168.206.106          False              6
# 18   192.168.100.221   mobile   192.168.85.206          False              6
# 37    192.168.74.195   mobile  192.168.212.112          False              8
# 83    192.168.96.217   mobile  192.168.217.117          False              6
# 86    192.168.96.217   mobile  192.168.215.115          False              6
# ..               ...      ...              ...            ...            ...
# 979   192.168.84.205   mobile  192.168.209.109          False              4
# 980   192.168.84.205  unknown  192.168.215.115          False              4
# 981   192.168.84.205   mobile  192.168.205.105          False              4
# 983   192.168.84.205      web  192.168.204.104          False              4
# 992   192.168.30.151  unknown  192.168.202.102          False              7
#
# [73 rows x 9 columns]

# %%
df_two_pizzas_dup = df_two_pizzas[df_two_pizzas["order"].isin(menu_two_items.loc[menu_two_items.duplicated()].index)]
df_two_pizzas_dup["order"].isna().sum()
# Out:
# 0

# %% [markdown]
# Отлично! В заказах с двумя пиццами, где мы не можем однозначно заполнить пропуски, их и не оказалось. Поэтому добавим результат нашей работы в исходную таблицу и перейдём к заказам с тремя пиццами:

# %%
for order_id in df_two_pizzas_no_dup["order_id"]:
    df_two_pizzas.loc[df_two_pizzas["order_id"] == order_id] = df_two_pizzas_no_dup

df_two_pizzas["order"].isna().sum()
# Out:
# 0

# %% [markdown]
# Успешно заполнили все пропуски в заказах с двумя пиццами. Переходим к трём:

# %%
menu_three_items = menu[menu.index.str.count(',') == 2]
menu_three_items
# Out:
#                                        order_price
# order
# 3 пиццы, Гавайская, Сицилийская               2364
# 3 пиццы, Дьябло, Мясной микс                  2438
# 3 пиццы, Мясной микс, Четыре сыра             2377
# 3 пиццы, Вегетарианская, Пеперони             2339
# 3 пиццы, Гавайская, Пеперони                  2349
# ...                                            ...
# Неаполитанская, Пеперони, Сицилийская         1605
# Дьябло, Пеперони, Сицилийская                 1635
# Маргарита, Пеперони, Сицилийская              1554
# Вегетарианская, Дьябло, Четыре сыра           1569
# Маргарита, Пеперони, Четыре сыра              1508
#
# [66 rows x 1 columns]

# %% [markdown]
# Аналогичным образом выведем все заказы, которые имеют уникальную цену:

# %%
df_three_pizzas = df[df["order_price"].isin(menu_three_items["order_price"])]
df_three_pizzas["order"].isna().sum()
# Out:
# 16

# %%
df_three_pizzas_no_dup = df_three_pizzas[~df_three_pizzas["order"].isin(menu_three_items.loc[menu_three_items.duplicated()].index)]
df_three_pizzas_no_dup["order"].isna().sum()
# Out:
# 16

# %% [markdown]
# 16 пропусков можем заполнить однозначно - сделаем это:

# %%
price_to_pizza = dict(zip(menu_three_items['order_price'], menu_three_items.index))
price_to_pizza
# Out:
# {2364: '3 пиццы, Гавайская, Сицилийская',
#  2438: '3 пиццы, Дьябло, Мясной микс',
#  2377: '3 пиццы, Мясной микс, Четыре сыра',
#  2339: '3 пиццы, Вегетарианская, Пеперони',
#  2349: '3 пиццы, Гавайская, Пеперони',
#  1588: 'Вегетарианская, Мясной микс, Четыре сыра',
#  1560: 'Вегетарианская, Гавайская, Пеперони',
#  1600: 'Вегетарианская, Дьябло, Неаполитанская',
#  1570: 'Вегетарианская, Неаполитанская, Пеперони',
#  1554: 'Маргарита, Пеперони, Сицилийская',
#  1559: 'Гавайская, Дьябло, Маргарита',
#  1529: 'Гавайская, Маргарита, Пеперони',
#  1629: 'Гавайская, Мясной микс, Пеперони',
#  2318: '3 пиццы, Гавайская, Четыре сыра',
#  1598: 'Гавайская, Мясной микс, Четыре сыра',
#  2369: '3 пиццы, Вегетарианская, Дьябло',
#  1584: 'Дьябло, Маргарита, Сицилийская',
#  1618: 'Дьябло, Маргарита, Мясной микс',
#  1569: 'Вегетарианская, Дьябло, Четыре сыра',
#  1589: 'Дьябло, Неаполитанская, Четыре сыра',
#  2404: '3 пиццы, Дьябло, Сицилийская',
#  2298: '3 пиццы, Гавайская, Маргарита',
#  1509: 'Вегетарианская, Гавайская, Маргарита',
#  1534: 'Вегетарианская, Маргарита, Сицилийская',
#  1578: 'Гавайская, Маргарита, Мясной микс',
#  2323: '3 пиццы, Маргарита, Сицилийская',
#  1498: 'Гавайская, Маргарита, Четыре сыра',
#  2423: '3 пиццы, Мясной микс, Сицилийская',
#  1609: 'Вегетарианская, Гавайская, Мясной микс',
#  1638: 'Дьябло, Мясной микс, Четыре сыра',
#  2357: '3 пиццы, Маргарита, Мясной микс',
#  1619: 'Вегетарианская, Мясной микс, Неаполитанская',
#  1654: 'Мясной микс, Неаполитанская, Сицилийская',
#  1644: 'Гавайская, Мясной микс, Сицилийская',
#  1610: 'Гавайская, Дьябло, Неаполитанская',
#  1669: 'Дьябло, Мясной микс, Неаполитанская',
#  1519: 'Вегетарианская, Маргарита, Неаполитанская',
#  2389: '3 пиццы, Дьябло, Пеперони',
#  1539: 'Маргарита, Неаполитанская, Пеперони',
#  1635: 'Дьябло, Пеперони, Сицилийская',
#  1615: 'Вегетарианская, Дьябло, Сицилийская',
#  1595: 'Гавайская, Неаполитанская, Сицилийская',
#  1564: 'Гавайская, Сицилийская, Четыре сыра',
#  1585: 'Вегетарианская, Неаполитанская, Сицилийская',
#  1605: 'Неаполитанская, Пеперони, Сицилийская',
#  1508: 'Маргарита, Пеперони, Четыре сыра'}

# %%
for index, row in df_three_pizzas_no_dup.iterrows():
    if pd.isnull(row['order']):
        order_price = row['order_price']
        df_three_pizzas_no_dup.at[index, 'order'] = price_to_pizza[order_price]
df_three_pizzas_no_dup
# Out:
#      order_id                                        order  order_price  \
# 23        973            Вегетарианская, Пеперони, 3 пиццы         2339
# 27        854           Мясной микс, Пеперони, Сицилийская         1654
# 31        971          Четыре сыра, Дьябло, Вегетарианская         1569
# 80        628              Гавайская, 3 пиццы, Сицилийская         2364
# 81        607              3 пиццы, Гавайская, Четыре сыра         2318
# ..        ...                                          ...          ...
# 905       808     Мясной микс, Неаполитанская, Сицилийская         1654
# 965       432       Вегетарианская, Дьябло, Неаполитанская         1600
# 966       466                 Гавайская, Маргарита, Дьябло         1559
# 994       996  Мясной микс, Неаполитанская, Вегетарианская         1619
# 999       947                    Пеперони, 3 пиццы, Дьябло         2389
#
#      user_id              ip   device      operator_ip  order_missing  \
# 23    520224  192.168.56.177      web  192.168.214.114          False
# 27    120373  192.168.65.186      web  192.168.216.116          False
# 31    126546  192.168.15.136  unknown  192.168.209.109          False
# 80    175019  192.168.96.217   mobile  192.168.216.116          False
# 81    666054  192.168.96.217  unknown  192.168.202.102           True
# ..       ...             ...      ...              ...            ...
# 905   912391  192.168.32.153  unknown  192.168.205.105           True
# 965   459391  192.168.84.205   mobile  192.168.208.108           True
# 966   924197  192.168.84.205   mobile  192.168.215.115          False
# 994   957297  192.168.22.143  unknown  192.168.213.113          False
# 999   684541  192.168.79.200   mobile  192.168.205.105          False
#
#     order_id_group
# 23               9
# 27               8
# 31               9
# 80               6
# 81               6
# ..             ...
# 905              8
# 965              4
# 966              4
# 994              9
# 999              9
#
# [79 rows x 9 columns]

# %% [markdown]
# Перейдём к пропускам, которые однозначно заполнить не получится:

# %%
df_three_pizzas_dup = df_three_pizzas[df_three_pizzas["order"].isin(menu_three_items.loc[menu_three_items.duplicated()].index)]
df_three_pizzas_dup["order"].isna().sum()
# Out:
# 0

# %% [markdown]
# И снова нам повезло - таких пропусков нет! Вернём нашу работу в основной датафрейм:

# %%
for order_id in df_three_pizzas_no_dup["order_id"]:
    df_three_pizzas.loc[df_three_pizzas["order_id"] == order_id] = df_three_pizzas_no_dup

df_three_pizzas["order"].isna().sum()
# Out:
# 0

# %% [markdown]
# Перейдём к заказам с четырьмя пиццами:

# %%
menu_four_items = menu[menu.index.str.count(',') == 3]
menu_four_items
# Out:
# Empty DataFrame
# Columns: [order_price]
# Index: []

# %% [markdown]
# Таких заказов нет - мы заполнили все пропуски!
#
# Вернём все наши данные в изначальный датафрейм df, чтобы проверить, что все пропуски заполнены успешно:

# %%
for order_id in df_one_pizza["order_id"]:
    df.loc[df["order_id"] == order_id] = df_one_pizza
for order_id in df_two_pizzas["order_id"]:
    df.loc[df["order_id"] == order_id] = df_two_pizzas
for order_id in df_three_pizzas["order_id"]:
    df.loc[df["order_id"] == order_id] = df_three_pizzas

df["order"].isna().sum()
# Out:
# 10

# %% [markdown]
# У нас остались ещё несколько незаполненных пропусков - выведем их на экран, чтобы посмотреть на них поподробнее:

# %%
df[df["order"].isna()]
# Out:
#      order_id order  order_price  user_id              ip   device  \
# 35        815   NaN         1649   300703  192.168.44.165      web
# 92        605   NaN         1544   396296  192.168.96.217  unknown
# 135       832   NaN         1623   615583   192.168.3.124  unknown
# 233       505   NaN         1549   685060   192.168.4.125      web
# 351       870   NaN         1649   353141  192.168.67.188      web
# 616       189   NaN         1684   506493  192.168.47.168   mobile
# 838       402   NaN         1579   798388  192.168.27.148   mobile
# 884       967   NaN         1625   409195  192.168.93.214      web
# 896       748   NaN         1549   863893  192.168.48.169   mobile
# 993       800   NaN         1590   418265  192.168.30.151      web
#
#          operator_ip  order_missing order_id_group
# 35    192.168.85.206           True              8
# 92   192.168.214.114           True              6
# 135   192.168.91.212           True              8
# 233  192.168.204.104           True              5
# 351  192.168.212.112           True              8
# 616  192.168.207.107           True              1
# 838  192.168.205.105           True              4
# 884   192.168.91.212           True              9
# 896  192.168.203.103           True              7
# 993  192.168.214.114           True              8

# %% [markdown]
# Судя по цене, во всех этих заказах три пиццы - и причина, почему они не появились в `menu_three_items` в том, что эти цены не фигурируют ни в каких не-пропущеных значениях. Поэтому заполним их простой модой по заказам с тремя пиццами (да, возможно, мы ошибёмся, но это всего 1% значений):

# %%
df = df.fillna(df_three_pizzas["order"].mode()[0])
df["order"].isna().sum()
# Out:
# 0

# %% [markdown]
# Тем самым мы заполнили все пропуски в заказах, и практически все из них - однозначно.

# %% [markdown]
# Поскольку ранее мы не смогли установить никаких взаимосвязей между пропусками и имеющимися данными, возможно, стоит посмотреть на распределение самих пропущеных значений - может быть, оно нам подскажет, в чём причина?

# %%
df_missing = pd.concat([orders, device], axis=1)
df_missing = df_missing.loc[:,~df_missing.columns.duplicated()].copy()
df_missing_filled = df.loc[df_missing["order"].isna()]
df_missing_filled
# Out:
#      order_id                         order  order_price  user_id  \
# 5         678                      Пеперони          530   263835
# 6         681                      Пеперони          530   948406
# 13        682                     Маргарита          479   642356
# 14        691            3 пиццы, Маргарита         1778   176837
# 20        969                Неаполитанская          530   603670
# ..        ...                           ...          ...      ...
# 976       422              Дьябло, Пеперони         1090   724452
# 985       978                     Маргарита          479   938521
# 993       800  3 пиццы, Дьябло, Мясной микс         1590   418265
# 997       918             Гавайская, Дьябло         1080   957570
# 998       948                        Дьябло          560   976203
#
#                   ip   device      operator_ip  order_missing order_id_group
# 5    192.168.100.221      web  192.168.209.109           True              6
# 6    192.168.100.221   mobile  192.168.213.113           True              6
# 13   192.168.100.221  unknown  192.168.206.106           True              6
# 14   192.168.100.221      web  192.168.203.103           True              6
# 20    192.168.61.182      web  192.168.209.109           True              9
# ..               ...      ...              ...            ...            ...
# 976   192.168.84.205   mobile  192.168.214.114           True              4
# 985   192.168.81.202      web   192.168.46.167           True              9
# 993   192.168.30.151      web  192.168.214.114           True              8
# 997   192.168.42.163  unknown  192.168.205.105           True              9
# 998   192.168.79.200  unknown  192.168.213.113           True              9
#
# [269 rows x 9 columns]

# %% [markdown]
# Изначально IP-адрес - серия из 32 двоичных бит. Единственная причина, по которой в таблице они представлены в виде десятичных чисел и разделены запятыми - удобочитаемость для человека. Поэтому попробуем перевести все наши IP-адреса в двоичный вид - возможно, это поможет нам найти проблему:

# %%
df_missing_filled["bin_ip"] = df["ip"].apply(lambda ip: ''.join(format(int(octet), '08b') for octet in ip.split('.')))
df_missing_filled["bin_operator_ip"] = df["operator_ip"].apply(lambda ip: ''.join(format(int(octet), '08b') for octet in ip.split('.')))
df_missing_filled
# Out:
# C:\Users\mtkar\AppData\Local\Temp\ipykernel_27128\3558190855.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing_filled["bin_ip"] = df["ip"].apply(lambda ip: ''.join(format(int(octet), '08b') for octet in ip.split('.')))
# C:\Users\mtkar\AppData\Local\Temp\ipykernel_27128\3558190855.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing_filled["bin_operator_ip"] = df["operator_ip"].apply(lambda ip: ''.join(format(int(octet), '08b') for octet in ip.split('.')))
#      order_id                         order  order_price  user_id  \
# 5         678                      Пеперони          530   263835
# 6         681                      Пеперони          530   948406
# 13        682                     Маргарита          479   642356
# 14        691            3 пиццы, Маргарита         1778   176837
# 20        969                Неаполитанская          530   603670
# ..        ...                           ...          ...      ...
# 976       422              Дьябло, Пеперони         1090   724452
# 985       978                     Маргарита          479   938521
# 993       800  3 пиццы, Дьябло, Мясной микс         1590   418265
# 997       918             Гавайская, Дьябло         1080   957570
# 998       948                        Дьябло          560   976203
#
#                   ip   device      operator_ip  order_missing order_id_group  \
# 5    192.168.100.221      web  192.168.209.109           True              6
# 6    192.168.100.221   mobile  192.168.213.113           True              6
# 13   192.168.100.221  unknown  192.168.206.106           True              6
# 14   192.168.100.221      web  192.168.203.103           True              6
# 20    192.168.61.182      web  192.168.209.109           True              9
# ..               ...      ...              ...            ...            ...
# 976   192.168.84.205   mobile  192.168.214.114           True              4
# 985   192.168.81.202      web   192.168.46.167           True              9
# 993   192.168.30.151      web  192.168.214.114           True              8
# 997   192.168.42.163  unknown  192.168.205.105           True              9
# 998   192.168.79.200  unknown  192.168.213.113           True              9
#
#                                bin_ip                   bin_operator_ip
# 5    11000000101010000110010011011101  11000000101010001101000101101101
# 6    11000000101010000110010011011101  11000000101010001101010101110001
# 13   11000000101010000110010011011101  11000000101010001100111001101010
# 14   11000000101010000110010011011101  11000000101010001100101101100111
# 20   11000000101010000011110110110110  11000000101010001101000101101101
# ..                                ...                               ...
# 976  11000000101010000101010011001101  11000000101010001101011001110010
# 985  11000000101010000101000111001010  11000000101010000010111010100111
# 993  11000000101010000001111010010111  11000000101010001101011001110010
# 997  11000000101010000010101010100011  11000000101010001100110101101001
# 998  11000000101010000100111111001000  11000000101010001101010101110001
#
# [269 rows x 11 columns]

# %% [markdown]
# Поскольку первые 6 цифр (в десятичном представлении - то есть первые 16 битов в двоичном) у всех значений одни и те же, отсечём их:

# %%
df_missing_filled["bin_ip"] = df_missing_filled["bin_ip"].apply(lambda ip: ip[16:])
df_missing_filled["bin_operator_ip"] = df_missing_filled["bin_operator_ip"].apply(lambda ip: ip[16:])
df_missing_filled = df_missing_filled.drop(["order_missing", "order_id_group"], axis=1)
df_missing_filled
# Out:
# C:\Users\mtkar\AppData\Local\Temp\ipykernel_27128\3814779525.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing_filled["bin_ip"] = df_missing_filled["bin_ip"].apply(lambda ip: ip[16:])
# C:\Users\mtkar\AppData\Local\Temp\ipykernel_27128\3814779525.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing_filled["bin_operator_ip"] = df_missing_filled["bin_operator_ip"].apply(lambda ip: ip[16:])
#      order_id                         order  order_price  user_id  \
# 5         678                      Пеперони          530   263835
# 6         681                      Пеперони          530   948406
# 13        682                     Маргарита          479   642356
# 14        691            3 пиццы, Маргарита         1778   176837
# 20        969                Неаполитанская          530   603670
# ..        ...                           ...          ...      ...
# 976       422              Дьябло, Пеперони         1090   724452
# 985       978                     Маргарита          479   938521
# 993       800  3 пиццы, Дьябло, Мясной микс         1590   418265
# 997       918             Гавайская, Дьябло         1080   957570
# 998       948                        Дьябло          560   976203
#
#                   ip   device      operator_ip            bin_ip  \
# 5    192.168.100.221      web  192.168.209.109  0110010011011101
# 6    192.168.100.221   mobile  192.168.213.113  0110010011011101
# 13   192.168.100.221  unknown  192.168.206.106  0110010011011101
# 14   192.168.100.221      web  192.168.203.103  0110010011011101
# 20    192.168.61.182      web  192.168.209.109  0011110110110110
# ..               ...      ...              ...               ...
# 976   192.168.84.205   mobile  192.168.214.114  0101010011001101
# 985   192.168.81.202      web   192.168.46.167  0101000111001010
# 993   192.168.30.151      web  192.168.214.114  0001111010010111
# 997   192.168.42.163  unknown  192.168.205.105  0010101010100011
# 998   192.168.79.200  unknown  192.168.213.113  0100111111001000
#
#       bin_operator_ip
# 5    1101000101101101
# 6    1101010101110001
# 13   1100111001101010
# 14   1100101101100111
# 20   1101000101101101
# ..                ...
# 976  1101011001110010
# 985  0010111010100111
# 993  1101011001110010
# 997  1100110101101001
# 998  1101010101110001
#
# [269 rows x 9 columns]

# %% [markdown]
# ### Подтверждение точного заполнения 82% пропусков

# %% [markdown]
# В процессе заполнения пропусков я обнаружил, что есть две большие "категории" пропусков: некоторые можно заполнить однозначно, поскольку такая цена присутствует только у одной пиццы (одной комбинации пицц), а некоторые - нет (хороший пример - пропуски с ценой 530 можно заполнить и Пеперрони, и Неаполитанской).
#
# Для заполнения пропусков я создал несколько "меню" - сводных таблиц с уникальными составами заказов и их ценами для заказов с одной, двумя и тремя позициями соответственно. Затем с помощью них я разделил наши данные на три части - в каждую из них отобрал все строки, где в заказе присутствует одна, две и три позиции соответственно (в этих секциях есть как пропущенные, так и не пропущенные значения). А каждую из этих трёх секций, в свою очередь, я разделил на две части: в первой все пропуски можно заполнить однозначно, во второй - нет. Например, для заказов с одной пиццей вторая часть сохранена в переменной `df_one_pizza_530`.
#
# Подсчитав, сколько из имеющихся пропусков были в "однозначных секциях", и разделив это количество на общее число пропусков, я и получил цифру 82%. Ниже я провёл эту операцию снова:

# %%
orders = pd.read_csv("orders.csv")
device = pd.read_csv("device.csv")
df = pd.concat([orders, device], axis=1)
df = df.loc[:,~df.columns.duplicated()].copy()

df_filled_precisely = pd.concat([df_one_pizza_no_530, df_two_pizzas_no_dup, df_three_pizzas_no_dup], axis=0)
nans_filled_precisely = df.loc[df_filled_precisely.index].isna()
nans_filled_precisely = nans_filled_precisely.loc[~nans_filled_precisely["order"] == False]["order"]
nans_filled_precisely
# Out:
# 13     True
# 22     True
# 25     True
# 29     True
# 57     True
#        ...
# 834    True
# 835    True
# 840    True
# 905    True
# 965    True
# Name: order, Length: 220, dtype: bool

# %% [markdown]
# Получили 220 пропусков, заполненных однозначно. Теперь посмотрим на общее количество пропусков и на долю однозначных пропусков среди всех имеющихся:

# %%
print(f"Общее количество пропусков: {df["order"].isna().sum()}")
print(f"Доля однозначно заполненных пропусков: {nans_filled_precisely.shape[0] / df["order"].isna().sum()}")
# Out:
# Общее количество пропусков: 269
# Доля однозначно заполненных пропусков: 0.8178438661710037
